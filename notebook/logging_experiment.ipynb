# %%
print("all_ok")
# Out:
# all_ok

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), "logs")

# %%
os.makedirs(logs_dir, exist_ok=True)

# %%
log_file = f"{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

# %%
log_file
# Out:
# '2025-08-13_06-30-23.log'

# %%
log_file_path = os.path.join(logs_dir, log_file)

# %%
logging.basicConfig(
    filename=log_file_path,
    level=logging.INFO,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s"
)

# %% [markdown]
# ## Above code will create a logging file

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
logger = logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
import structlog

# %%
log = structlog.get_logger()

# %%
log.info("This is a structlog info message", userid=123, filename="example.txt")
# Out:
# 2025-08-19 12:08:31 [info     ] This is a structlog info message filename=example.txt userid=123
