# %%
print("all_ok")
# Out:
# all_ok

# %%
import os
from pathlib import Path
path = os.path.join(os.getcwd(), "../data", "document_analyzer")
data_dir = "data"
path = Path(r"C:\Users\hp\OneDrive\Documents\Kartek\LLMOPS\Document_Portal") / data_dir

path
# Out:
# WindowsPath('C:/Users/hp/OneDrive/Documents/Kartek/LLMOPS/Document_Portal/data')
